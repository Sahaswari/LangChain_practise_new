# %%
import openai
from typing import List

# %% [markdown]
# ### Vanilla OpenAI

# %%
client = openai.OpenAI()

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": "Hello!"}]
)
response
response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 client = openai.OpenAI()
# ----> 3 response = client.chat.completions.create(
#       4     model="gpt-3.5-turbo",
#       5     messages=[{"role": "user", "content": "Hello!"}]
#       6 )
#       7 response
#       8 response.choices[0].message.content
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
prompt_template = "Tell me a short joke about {topic}"
client = openai.OpenAI()

def call_chat_model(messages: List[dict]) -> str:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
    )
    return response.choices[0].message.content

def invoke_chain(topic: str) -> str:
    prompt_value = prompt_template.format(topic=topic)
    messages = [{"role": "user", "content": prompt_value}]
    return call_chat_model(messages)

invoke_chain("a parrot")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 16
#      13     messages = [{"role": "user", "content": prompt_value}]
#      14     return call_chat_model(messages)
# ---> 16 invoke_chain("a parrot")
#
# Cell In[3], line 14, in invoke_chain(topic)
#      12 prompt_value = prompt_template.format(topic=topic)
#      13 messages = [{"role": "user", "content": prompt_value}]
# ---> 14 return call_chat_model(messages)
#
# Cell In[3], line 5, in call_chat_model(messages)
#       4 def call_chat_model(messages: List[dict]) -> str:
# ----> 5     response = client.chat.completions.create(
#       6         model="gpt-3.5-turbo",
#       7         messages=messages,
#       8     )
#       9     return response.choices[0].message.content
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ### With LangChain

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from dotenv import load_dotenv

load_dotenv()

#from langchain_mistralai.chat_models import ChatMistralAI


prompt = ChatPromptTemplate.from_template(
    "Tell me a short joke about {topic}"
)
output_parser = StrOutputParser()
model = ChatOpenAI(model="gpt-3.5-turbo")
#model = ChatMistralAI(api_key=api_key)
chain = (
    {"topic": RunnablePassthrough()}
    | prompt
    | model
    | output_parser
)

chain.invoke("a parrot")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 25
#      17 #model = ChatMistralAI(api_key=api_key)
#      18 chain = (
#      19     {"topic": RunnablePassthrough()}
#      20     | prompt
#      21     | model
#      22     | output_parser
#      23 )
# ---> 25 chain.invoke("a parrot")
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:689, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     687     generation_info = {"headers": dict(raw_response.headers)}
#     688 else:
# --> 689     response = self.client.create(**payload)
#     690 return self._create_chat_result(response, generation_info)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ### What is this "|"?

# %%
class CustomLCEL:
    def __init__(self, value):
        self.value = value

    def __or__(self, other):
        if callable(other):
            return CustomLCEL(other(self.value))
        else:
            raise ValueError("Right operand must be callable")

    def result(self):
        return self.value

def to_uppercase(s):
    return s.upper()

def add_exclamation(s):
    return s + "!"

def reverse_string(s):
    return s[::-1]

# %%
custom_chain = (
    CustomLCEL("hello world")
    | to_uppercase
    | add_exclamation
    | reverse_string
)

result = custom_chain.result()
print(result)
# Out:
# !DLROW OLLEH

# %% [markdown]
# ### Runnable Interface (Stream, Invoke, Batch)

# %%
for s in chain.stream({"topic": "bears"}):
    print(s.content, end="", flush=True)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for s in chain.stream({"topic": "bears"}):
#       2     print(s.content, end="", flush=True)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3407, in RunnableSequence.stream(self, input, config, **kwargs)
#    3401 def stream(
#    3402     self,
#    3403     input: Input,
#    3404     config: Optional[RunnableConfig] = None,
#    3405     **kwargs: Optional[Any],
#    3406 ) -> Iterator[Output]:
# -> 3407     yield from self.transform(iter([input]), config, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3394, in RunnableSequence.transform(self, input, config, **kwargs)
#    3388 def transform(
#    3389     self,
#    3390     input: Iterator[Input],
#    3391     config: Optional[RunnableConfig] = None,
#    3392     **kwargs: Optional[Any],
#    3393 ) -> Iterator[Output]:
# -> 3394     yield from self._transform_stream_with_config(
#    3395         input,
#    3396         self._transform,
#    3397         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3398         **kwargs,
#    3399     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:2197, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2195 try:
#    2196     while True:
# -> 2197         chunk: Output = context.run(next, iterator)  # type: ignore
#    2198         yield chunk
#    2199         if final_output_supported:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3357, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3354     else:
#    3355         final_pipeline = step.transform(final_pipeline, config)
# -> 3357 yield from final_pipeline
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\output_parsers\transform.py:64, in BaseTransformOutputParser.transform(self, input, config, **kwargs)
#      48 def transform(
#      49     self,
#      50     input: Iterator[Union[str, BaseMessage]],
#      51     config: Optional[RunnableConfig] = None,
#      52     **kwargs: Any,
#      53 ) -> Iterator[T]:
#      54     """Transform the input into the output format.
#      55
#      56     Args:
#    (...)
#      62         The transformed output.
#      63     """
# ---> 64     yield from self._transform_stream_with_config(
#      65         input, self._transform, config, run_type="parser"
#      66     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:2161, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2159 input_for_tracing, input_for_transform = tee(input, 2)
#    2160 # Start the input iterator to ensure the input Runnable starts before this one
# -> 2161 final_input: Optional[Input] = next(input_for_tracing, None)
#    2162 final_input_supported = True
#    2163 final_output: Optional[Output] = None
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:1431, in Runnable.transform(self, input, config, **kwargs)
#    1428             final = ichunk
#    1430 if got_first_val:
# -> 1431     yield from self.stream(final, config, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:420, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     413 except BaseException as e:
#     414     run_manager.on_llm_error(
#     415         e,
#     416         response=LLMResult(
#     417             generations=[[generation]] if generation else []
#     418         ),
#     419     )
# --> 420     raise e
#     421 else:
#     422     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:400, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     397     self.rate_limiter.acquire(blocking=True)
#     399 try:
# --> 400     for chunk in self._stream(messages, stop=stop, **kwargs):
#     401         if chunk.message.id is None:
#     402             chunk.message.id = f"run-{run_manager.run_id}"
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:640, in BaseChatOpenAI._stream(self, messages, stop, run_manager, **kwargs)
#     638     base_generation_info = {"headers": dict(raw_response.headers)}
#     639 else:
# --> 640     response = self.client.create(**payload)
#     641 with response:
#     642     is_first_chunk = True
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
chain.invoke({"topic": "bears"})
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 chain.invoke({"topic": "bears"})
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:689, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     687     generation_info = {"headers": dict(raw_response.headers)}
#     688 else:
# --> 689     response = self.client.create(**payload)
#     690 return self._create_chat_result(response, generation_info)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
chain.batch([{"topic": "bears"}, {"topic": "cats"}])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 chain.batch([{"topic": "bears"}, {"topic": "cats"}])
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3169, in RunnableSequence.batch(self, inputs, config, return_exceptions, **kwargs)
#    3167     else:
#    3168         for i, step in enumerate(self.steps):
# -> 3169             inputs = step.batch(
#    3170                 inputs,
#    3171                 [
#    3172                     # each step a child run of the corresponding root run
#    3173                     patch_config(
#    3174                         config, callbacks=rm.get_child(f"seq:step:{i+1}")
#    3175                     )
#    3176                     for rm, config in zip(run_managers, configs)
#    3177                 ],
#    3178                 return_exceptions=return_exceptions,
#    3179                 **(kwargs if i == 0 else {}),
#    3180             )
#    3182 # finish the root runs
#    3183 except BaseException as e:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:791, in Runnable.batch(self, inputs, config, return_exceptions, **kwargs)
#     788     return cast(list[Output], [invoke(inputs[0], configs[0])])
#     790 with get_executor_for_config(configs[0]) as executor:
# --> 791     return cast(list[Output], list(executor.map(invoke, inputs, configs)))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\config.py:527, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     526 def _wrapped_fn(*args: Any) -> T:
# --> 527     return contexts.pop().run(fn, *args)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:784, in Runnable.batch.<locals>.invoke(input, config)
#     782         return e
#     783 else:
# --> 784     return self.invoke(input, config, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:689, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     687     generation_info = {"headers": dict(raw_response.headers)}
#     688 else:
# --> 689     response = self.client.create(**payload)
#     690 return self._create_chat_result(response, generation_info)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1044 if remaining_retries > 0 and self._should_retry(err.response):
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#    1057 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
async for s in chain.astream({"topic": "bears"}):
    print(s.content, end="", flush=True)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 async for s in chain.astream({"topic": "bears"}):
#       2     print(s.content, end="", flush=True)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3432, in RunnableSequence.astream(self, input, config, **kwargs)
#    3429 async def input_aiter() -> AsyncIterator[Input]:
#    3430     yield input
# -> 3432 async for chunk in self.atransform(input_aiter(), config, **kwargs):
#    3433     yield chunk
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3415, in RunnableSequence.atransform(self, input, config, **kwargs)
#    3409 async def atransform(
#    3410     self,
#    3411     input: AsyncIterator[Input],
#    3412     config: Optional[RunnableConfig] = None,
#    3413     **kwargs: Optional[Any],
#    3414 ) -> AsyncIterator[Output]:
# -> 3415     async for chunk in self._atransform_stream_with_config(
#    3416         input,
#    3417         self._atransform,
#    3418         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3419         **kwargs,
#    3420     ):
#    3421         yield chunk
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:2303, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2301 while True:
#    2302     if asyncio_accepts_context():
# -> 2303         chunk: Output = await asyncio.create_task(  # type: ignore[call-arg]
#    2304             py_anext(iterator),  # type: ignore[arg-type]
#    2305             context=context,
#    2306         )
#    2307     else:
#    2308         chunk = cast(Output, await py_anext(iterator))
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:3385, in RunnableSequence._atransform(self, input, run_manager, config, **kwargs)
#    3383     else:
#    3384         final_pipeline = step.atransform(final_pipeline, config)
# -> 3385 async for output in final_pipeline:
#    3386     yield output
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\output_parsers\transform.py:84, in BaseTransformOutputParser.atransform(self, input, config, **kwargs)
#      68 async def atransform(
#      69     self,
#      70     input: AsyncIterator[Union[str, BaseMessage]],
#      71     config: Optional[RunnableConfig] = None,
#      72     **kwargs: Any,
#      73 ) -> AsyncIterator[T]:
#      74     """Async transform the input into the output format.
#      75
#      76     Args:
#    (...)
#      82         The transformed output.
#      83     """
# ---> 84     async for chunk in self._atransform_stream_with_config(
#      85         input, self._atransform, config, run_type="parser"
#      86     ):
#      87         yield chunk
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:2261, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2259 input_for_tracing, input_for_transform = atee(input, 2)
#    2260 # Start the input iterator to ensure the input Runnable starts before this one
# -> 2261 final_input: Optional[Input] = await py_anext(input_for_tracing, None)
#    2262 final_input_supported = True
#    2263 final_output: Optional[Output] = None
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\utils\aiter.py:76, in py_anext.<locals>.anext_impl()
#      69 async def anext_impl() -> Union[T, Any]:
#      70     try:
#      71         # The C code is way more low-level than this, as it implements
#      72         # all methods of the iterator protocol. In this implementation
#      73         # we're relying on higher-level coroutine concepts, but that's
#      74         # exactly what we want -- crosstest pure-Python high-level
#      75         # implementation and low-level C anext() iterators.
# ---> 76         return await __anext__(iterator)
#      77     except StopAsyncIteration:
#      78         return default
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\utils\aiter.py:125, in tee_peer(iterator, buffer, peers, lock)
#     123     continue
#     124 try:
# --> 125     item = await iterator.__anext__()
#     126 except StopAsyncIteration:
#     127     break
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\runnables\base.py:1473, in Runnable.atransform(self, input, config, **kwargs)
#    1470             final = ichunk
#    1472 if got_first_val:
# -> 1473     async for output in self.astream(final, config, **kwargs):
#    1474         yield output
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:494, in BaseChatModel.astream(self, input, config, stop, **kwargs)
#     489 except BaseException as e:
#     490     await run_manager.on_llm_error(
#     491         e,
#     492         response=LLMResult(generations=[[generation]] if generation else []),
#     493     )
# --> 494     raise e
#     495 else:
#     496     await run_manager.on_llm_end(
#     497         LLMResult(generations=[[generation]]),
#     498     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:472, in BaseChatModel.astream(self, input, config, stop, **kwargs)
#     470 generation: Optional[ChatGenerationChunk] = None
#     471 try:
# --> 472     async for chunk in self._astream(
#     473         messages,
#     474         stop=stop,
#     475         **kwargs,
#     476     ):
#     477         if chunk.message.id is None:
#     478             chunk.message.id = f"run-{run_manager.run_id}"
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:2066, in ChatOpenAI._astream(self, stream_usage, *args, **kwargs)
#    2063 if stream_usage:
#    2064     kwargs["stream_options"] = {"include_usage": stream_usage}
# -> 2066 async for chunk in super()._astream(*args, **kwargs):
#    2067     yield chunk
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:774, in BaseChatOpenAI._astream(self, messages, stop, run_manager, **kwargs)
#     772     base_generation_info = {"headers": dict(raw_response.headers)}
#     773 else:
# --> 774     response = await self.async_client.create(**payload)
#     775 async with response:
#     776     is_first_chunk = True
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\resources\chat\completions.py:1661, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1620 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1621 async def create(
#    1622     self,
#    (...)
#    1658     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1659 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1660     validate_response_format(response_format)
# -> 1661     return await self._post(
#    1662         "/chat/completions",
#    1663         body=await async_maybe_transform(
#    1664             {
#    1665                 "messages": messages,
#    1666                 "model": model,
#    1667                 "audio": audio,
#    1668                 "frequency_penalty": frequency_penalty,
#    1669                 "function_call": function_call,
#    1670                 "functions": functions,
#    1671                 "logit_bias": logit_bias,
#    1672                 "logprobs": logprobs,
#    1673                 "max_completion_tokens": max_completion_tokens,
#    1674                 "max_tokens": max_tokens,
#    1675                 "metadata": metadata,
#    1676                 "modalities": modalities,
#    1677                 "n": n,
#    1678                 "parallel_tool_calls": parallel_tool_calls,
#    1679                 "prediction": prediction,
#    1680                 "presence_penalty": presence_penalty,
#    1681                 "response_format": response_format,
#    1682                 "seed": seed,
#    1683                 "service_tier": service_tier,
#    1684                 "stop": stop,
#    1685                 "store": store,
#    1686                 "stream": stream,
#    1687                 "stream_options": stream_options,
#    1688                 "temperature": temperature,
#    1689                 "tool_choice": tool_choice,
#    1690                 "tools": tools,
#    1691                 "top_logprobs": top_logprobs,
#    1692                 "top_p": top_p,
#    1693                 "user": user,
#    1694             },
#    1695             completion_create_params.CompletionCreateParams,
#    1696         ),
#    1697         options=make_request_options(
#    1698             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1699         ),
#    1700         cast_to=ChatCompletion,
#    1701         stream=stream or False,
#    1702         stream_cls=AsyncStream[ChatCompletionChunk],
#    1703     )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1843, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1829 async def post(
#    1830     self,
#    1831     path: str,
#    (...)
#    1838     stream_cls: type[_AsyncStreamT] | None = None,
#    1839 ) -> ResponseT | _AsyncStreamT:
#    1840     opts = FinalRequestOptions.construct(
#    1841         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1842     )
# -> 1843     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1537, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1534 else:
#    1535     retries_taken = 0
# -> 1537 return await self._request(
#    1538     cast_to=cast_to,
#    1539     options=options,
#    1540     stream=stream,
#    1541     stream_cls=stream_cls,
#    1542     retries_taken=retries_taken,
#    1543 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1623, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1621 if remaining_retries > 0 and self._should_retry(err.response):
#    1622     await err.response.aclose()
# -> 1623     return await self._retry_request(
#    1624         input_options,
#    1625         cast_to,
#    1626         retries_taken=retries_taken,
#    1627         response_headers=err.response.headers,
#    1628         stream=stream,
#    1629         stream_cls=stream_cls,
#    1630     )
#    1632 # If the response is streamed then we need to explicitly read the response
#    1633 # to completion before attempting to access the response text.
#    1634 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1670, in AsyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1666 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1668 await anyio.sleep(timeout)
# -> 1670 return await self._request(
#    1671     options=options,
#    1672     cast_to=cast_to,
#    1673     retries_taken=retries_taken + 1,
#    1674     stream=stream,
#    1675     stream_cls=stream_cls,
#    1676 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1623, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1621 if remaining_retries > 0 and self._should_retry(err.response):
#    1622     await err.response.aclose()
# -> 1623     return await self._retry_request(
#    1624         input_options,
#    1625         cast_to,
#    1626         retries_taken=retries_taken,
#    1627         response_headers=err.response.headers,
#    1628         stream=stream,
#    1629         stream_cls=stream_cls,
#    1630     )
#    1632 # If the response is streamed then we need to explicitly read the response
#    1633 # to completion before attempting to access the response text.
#    1634 if not err.response.is_closed:
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1670, in AsyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1666 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1668 await anyio.sleep(timeout)
# -> 1670 return await self._request(
#    1671     options=options,
#    1672     cast_to=cast_to,
#    1673     retries_taken=retries_taken + 1,
#    1674     stream=stream,
#    1675     stream_cls=stream_cls,
#    1676 )
#
# File f:\AI courses\LangChain\Langchain-Practise\LangChain-new_code_practise\LangChain_practise_new\.venv\Lib\site-packages\openai\_base_client.py:1638, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1635         await err.response.aread()
#    1637     log.debug("Re-raising status error")
# -> 1638     raise self._make_status_error_from_response(err.response) from None
#    1640 return await self._process_response(
#    1641     cast_to=cast_to,
#    1642     options=options,
#    (...)
#    1646     retries_taken=retries_taken,
#    1647 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
await chain.ainvoke({"topic": "bears"})

# %%
await chain.abatch([{"topic": "bears"}])
